# %%
from ultralytics import YOLO

# 学習済みモデルをロード
model = YOLO("yolo11n.pt")

url = r"C:\Users\01A1561\Downloads\95060_640x360.mp4"
results = model(url,save=True)

print("分析完了")
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/678) C:\Users\01A1561\Downloads\98999_640x360.mp4: 384x640 10 cars, 184.8ms
# video 1/1 (frame 2/678) C:\Users\01A1561\Downloads\98999_640x360.mp4: 384x640 8 cars, 54.5ms
# video 1/1 (frame 3/678) C:\Users\01A1561\Downloads\98999_640x360.mp4: 384x640 8 cars, 58.6ms
# video 1/1 (frame 4/678) C:\Users\01A1561\Downloads\98999_640x360.mp4: 384x640 7 cars, 45.0ms
# ...
