# %%
from ultralytics import YOLO

# 学習済みモデルをロード
model = YOLO("best.pt")

url = r"C:\Users\01A1561\Downloads\98996_640x360.mp4"
results = model(url,save=True)

for frame_idx, result in enumerate(results):
    boxes = result.boxes  # 検出結果のボックス情報
    for box in boxes:
        cls_id = int(box.cls[0])        # クラスID
        cls_name = model.names[cls_id]  # クラス名
        conf = float(box.conf[0])       # 信頼度 (0.0〜1.0)
        print(f"フレーム {frame_idx}: 検出={cls_name}, 信頼度={conf:.2f}")

print("分析完了")
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 298.9ms
# video 1/1 (frame 2/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 59.9ms
# video 1/1 (frame 3/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 61.4ms
# video 1/1 (frame 4/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 60.1ms
# video 1/1 (frame 5/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 64.7ms
# video 1/1 (frame 6/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 73.6ms
# video 1/1 (frame 7/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 81.6ms
# video 1/1 (frame 8/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 3 cars, 69.9ms
# video 1/1 (frame 9/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 59.8ms
# video 1/1 (frame 10/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 58.5ms
# video 1/1 (frame 11/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 64.2ms
# video 1/1 (frame 12/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 63.9ms
# video 1/1 (frame 13/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 67.4ms
# video 1/1 (frame 14/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 68.0ms
# video 1/1 (frame 15/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 71.3ms
# video 1/1 (frame 16/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 81.6ms
# video 1/1 (frame 17/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 90.9ms
# video 1/1 (frame 18/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 100.1ms
# video 1/1 (frame 19/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 86.5ms
# video 1/1 (frame 20/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 82.8ms
# video 1/1 (frame 21/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 92.6ms
# video 1/1 (frame 22/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 159.5ms
# video 1/1 (frame 23/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 107.3ms
# video 1/1 (frame 24/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 114.5ms
# video 1/1 (frame 25/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 108.7ms
# video 1/1 (frame 26/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 107.2ms
# video 1/1 (frame 27/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 125.2ms
# video 1/1 (frame 28/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 181.3ms
# video 1/1 (frame 29/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 172.0ms
# video 1/1 (frame 30/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 145.1ms
# video 1/1 (frame 31/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 153.7ms
# video 1/1 (frame 32/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 (no detections), 137.1ms
# video 1/1 (frame 33/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 139.8ms
# video 1/1 (frame 34/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 142.1ms
# video 1/1 (frame 35/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 113.9ms
# video 1/1 (frame 36/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 112.4ms
# video 1/1 (frame 37/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 106.6ms
# video 1/1 (frame 38/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 96.6ms
# video 1/1 (frame 39/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 100.6ms
# video 1/1 (frame 40/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 88.8ms
# video 1/1 (frame 41/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 88.3ms
# video 1/1 (frame 42/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 110.9ms
# video 1/1 (frame 43/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 208.4ms
# video 1/1 (frame 44/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 151.4ms
# video 1/1 (frame 45/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 233.4ms
# video 1/1 (frame 46/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 220.9ms
# video 1/1 (frame 47/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 120.2ms
# video 1/1 (frame 48/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 104.3ms
# video 1/1 (frame 49/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 112.6ms
# video 1/1 (frame 50/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 109.9ms
# video 1/1 (frame 51/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 110.3ms
# video 1/1 (frame 52/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 98.6ms
# video 1/1 (frame 53/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 91.0ms
# video 1/1 (frame 54/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 90.5ms
# video 1/1 (frame 55/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 101.4ms
# video 1/1 (frame 56/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 122.1ms
# video 1/1 (frame 57/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 117.2ms
# video 1/1 (frame 58/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 132.9ms
# video 1/1 (frame 59/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 128.3ms
# video 1/1 (frame 60/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car,
918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 105.9ms
# video 1/1 (frame 193/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 bike, 121.6ms
# video 1/1 (frame 194/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 1 bike, 92.9ms
# video 1/1 (frame 195/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 94.1ms
# video 1/1 (frame 196/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 104.7ms
# video 1/1 (frame 197/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 112.4ms
# video 1/1 (frame 198/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 4 cars, 137.7ms
# video 1/1 (frame 199/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 3 cars, 148.8ms
# video 1/1 (frame 200/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 108.3ms
# video 1/1 (frame 201/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 164.4ms
# video 1/1 (frame 202/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 4 cars, 1 track, 1 bike, 152.0ms
# video 1/1 (frame 203/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 168.2ms
# video 1/1 (frame 204/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 144.7ms
# video 1/1 (frame 205/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 1 bike, 152.7ms
# video 1/1 (frame 206/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 1 bike, 148.4ms
# video 1/1 (frame 207/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 171.8ms
# video 1/1 (frame 208/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 149.2ms
# video 1/1 (frame 209/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 1 track, 232.4ms
# video 1/1 (frame 210/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 140.3ms
# video 1/1 (frame 211/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 133.4ms
# video 1/1 (frame 212/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 107.0ms
# video 1/1 (frame 213/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 123.5ms
# video 1/1 (frame 214/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 130.1ms
# video 1/1 (frame 215/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 137.3ms
# video 1/1 (frame 216/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 133.6ms
# video 1/1 (frame 217/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 133.7ms
# video 1/1 (frame 218/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 146.8ms
# video 1/1 (frame 219/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 138.6ms
# video 1/1 (frame 220/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 137.6ms
# video 1/1 (frame 221/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 199.2ms
# video 1/1 (frame 222/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 154.9ms
# video 1/1 (frame 223/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 143.2ms
# video 1/1 (frame 224/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 141.5ms
# video 1/1 (frame 225/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 131.2ms
# video 1/1 (frame 226/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 147.6ms
# video 1/1 (frame 227/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 143.6ms
# video 1/1 (frame 228/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 130.7ms
# video 1/1 (frame 229/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 126.8ms
# video 1/1 (frame 230/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 111.5ms
# video 1/1 (frame 231/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 113.9ms
# video 1/1 (frame 232/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 107.6ms
# video 1/1 (frame 233/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 125.3ms
# video 1/1 (frame 234/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 1 car, 100.8ms
# video 1/1 (frame 235/918) C:\Users\01A1561\Downloads\98996_640x360.mp4: 384x640 2 cars, 95.2ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 model = YOLO("best.pt")
#       6 url = r"C:\Users\01A1561\Downloads\98996_640x360.mp4"
# ----> 7 results = model(url,save=True)
#       9 for frame_idx, result in enumerate(results):
#      10     boxes = result.boxes  # 検出結果のボックス情報
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\engine\model.py:178, in Model.__call__(self, source, stream, **kwargs)
#     150 def __call__(
#     151     self,
#     152     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     153     stream: bool = False,
#     154     **kwargs: Any,
#     155 ) -> Iterator[Results | torch.Tensor] | list[Results] | list[torch.Tensor]:
#     156     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     157
#     158     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    176         ...     print(f"Detected {len(r)} objects in image")
#     177     """
# --> 178     return self.predict(source, stream, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\engine\model.py:542, in Model.predict(self, source, stream, predictor, **kwargs)
#     540 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     541     self.predictor.set_prompts(prompts)
# --> 542 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\engine\predictor.py:229, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227     return self.stream_inference(source, model, *args, **kwargs)
#     228 else:
# --> 229     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\utils\_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\engine\predictor.py:338, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     336 # Inference
#     337 with profilers[1]:
# --> 338     preds = self.inference(im, *args, **kwargs)
#     339     if self.args.embed:
#     340         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\engine\predictor.py:186, in BasePredictor.inference(self, im, *args, **kwargs)
#     180 """Run inference on a given image using the specified model and arguments."""
#     181 visualize = (
#     182     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     183     if self.args.visualize and (not self.source_type.tensor)
#     184     else False
#     185 )
# --> 186 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\autobackend.py:278, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     275 if self.format == "pt":
#     276     forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
# --> 278 y = self.backend.forward(im, **forward_kwargs)
#     280 if isinstance(y, (list, tuple)):
#     281     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\backends\pytorch.py:90, in PyTorchBackend.forward(self, im, augment, visualize, embed, **kwargs)
#      75 def forward(
#      76     self, im: torch.Tensor, augment: bool = False, visualize: bool = False, embed: list | None = None, **kwargs: Any
#      77 ) -> torch.Tensor | list[torch.Tensor]:
#      78     """Run native PyTorch inference with support for augmentation, visualization, and embeddings.
#      79
#      80     Args:
#    (...)     88         (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89     """
# ---> 90     return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\tasks.py:154, in BaseModel.forward(self, x, *args, **kwargs)
#     152 if isinstance(x, dict):  # for cases of training and validating while training.
#     153     return self.loss(x, *args, **kwargs)
# --> 154 return self.predict(x, *args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\tasks.py:171, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     169 if augment:
#     170     return self._predict_augment(x)
# --> 171 return self._predict_once(x, profile, visualize, embed)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\tasks.py:193, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     191 if profile:
#     192     self._profile_one_layer(m, x, dt)
# --> 193 x = m(x)  # run
#     194 y.append(x if m.i in self.save else None)  # save output
#     195 if visualize:
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:312, in C2f.forward(self, x)
#     310 y = list(self.cv1(x).chunk(2, 1))
#     311 y.extend(m(y[-1]) for m in self.m)
# --> 312 return self.cv2(torch.cat(y, 1))
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\YOLO\YOLO\.venv\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:
